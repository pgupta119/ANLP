# %% [markdown]
# <a href="https://colab.research.google.com/github/pgupta119/ANLP/blob/main/Untitled10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive/')
# Out:
# Drive already mounted at /content/gdrive/; to attempt to forcibly remount, call drive.mount("/content/gdrive/", force_remount=True).

# %%
import sys

# %%
import sys
sys.path.append('/content/gdrive/My Drive/ASTER')

# %%
# !python2.7 /content/gdrive/MyDrive/ASTER/Event-to-Sentence/nmt.py --config /content/gdrive/MyDrive/ASTER/Event-to-Sentence/config.json
# Out:
# Reading data ...
# Reading source data ...
# Constructing source vocabulary ...
# Reading target data ...
# Constructing target vocabulary ...
# Reading source data ...
# Constructing source vocabulary ...
# Reading target data ...
# Constructing target vocabulary ...
# 2021-03-12 22:11:07,453 - INFO - Model Parameters :
# 2021-03-12 22:11:07,453 - INFO - Task : translation
# 2021-03-12 22:11:07,453 - INFO - Model : attention
# 2021-03-12 22:11:07,453 - INFO - Source Type :
# 2021-03-12 22:11:07,453 - INFO - Target Type :
# 2021-03-12 22:11:07,453 - INFO - Source Word Embedding Dim  : 512
# 2021-03-12 22:11:07,453 - INFO - Target Word Embedding Dim  : 512
# 2021-03-12 22:11:07,454 - INFO - Source RNN Hidden Dim  : 512
# 2021-03-12 22:11:07,454 - INFO - Target RNN Hidden Dim  : 512
# 2021-03-12 22:11:07,454 - INFO - Source RNN Depth : 3
# 2021-03-12 22:11:07,454 - INFO - Target RNN Depth : 1
# 2021-03-12 22:11:07,454 - INFO - Source RNN Bidirectional  : False
# ...
